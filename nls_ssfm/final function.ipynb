# %%
from numpy import *
from matplotlib import *
from pylab import *
import pandas as pd
from tqdm import tqdm_notebook as tqdm

# %%
df = pd.read_csv("nls-initial-profile.txt" , sep='\\s+', header=None)
df2 = pd.read_csv("nls-final-profile.txt" , sep='\\s+', header=None)
df.columns = ['x', 'UX']
x = df['x'].values
y = df['UX'].values

# %%
df2.columns = ['f2','x2']
f2 = df2['f2'].values
x2 = df2['x2'].values

# %%
figure(figsize=(7, 5))
plot(x,y,"-",color="cyan",label="t=0"),
#plot(f2,x2,"-",color="red",label="t=2")
#xticks(np.linspace(0, 2*pi, 5), ['0', r'$\pi/2$', r'$\pi$', r'$3\pi/2$', r'$2\pi$'])
xlabel("x")
ylabel("|U(x,t)|")
title("initial function ")
legend()
savefig("nls4-initial and final.png")
